# %% [markdown]
# Prompt: Beri kode untuk connect gcolab dengan gdrive!

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Prompt: Beri kode untuk read dataset sebagai dataframe!

# %%
import pandas as pd

df = pd.read_csv('/content/StudentsPerformance.csv')

# %% [markdown]
# Prompt: Beri kode untuk menampilkan baris dataframe!

# %%
print(df.head())
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# Info terkait kolom parental level of education:
#
# - Bachelor's degree: Orang tua siswa telah menyelesaikan pendidikan sarjana (S1).
# - Master's degree: Orang tua siswa telah menyelesaikan pendidikan pascasarjana (S2).
# - Associate's degree: Gelar akademik yang biasanya didapat setelah dua tahun kuliah, biasanya di perguruan tinggi komunitas.
# - Some college: Orang tua telah berkuliah di universitas tetapi tidak sampai lulus.
# - High school: Orang tua siswa hanya menyelesaikan pendidikan tingkat SMA.
# - Some high school: Orang tua siswa hanya bersekolah di SMA tetapi tidak menyelesaikannya.
#
# Info terkait kolom lunch:
#
# - Standard: Siswa membayar untuk makanan siang dengan harga penuh, yang biasanya menunjukkan kondisi ekonomi keluarga yang baik.
# - Free/reduced: Siswa menerima makanan siang gratis atau dengan potongan harga, yang biasanya diberikan kepada keluarga dengan penghasilan lebih rendah atau siswa yang memenuhi syarat program subsidi.

# %% [markdown]
# Prompt: Beri kode untuk menampilkan info dari dataframe!

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
# Prompt:
#
# Aku punya dataset berikut:
# StudentsPerformance.csv
#
# Dan informasi terkait dataframe saya sebagai berikut:
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#     Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#
#  1   race/ethnicity               1000 non-null   object
#
#  2   parental level of education  1000 non-null   object
#
#  3   lunch                        1000 non-null   object
#
#  4   test preparation course      1000 non-null   object
#
#  5   math score                   1000 non-null   int64
#
#  6   reading score                1000 non-null   int64
#
#  7   writing score                1000 non-null   int64
#
# dtypes: int64(3), object(5)
#
# Beri sample kode python untuk dapat menampilkan persentase dari data bertipe kategorikal dalam bentuk pie chart, sehingga saya bisa copy paste ke google colab.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Memuat dataset
df = pd.read_csv('/content/StudentsPerformance.csv')

# Menampilkan persentase data untuk kolom kategorikal dalam bentuk pie chart
categorical_columns = ['gender', 'race/ethnicity', 'parental level of education', 'lunch', 'test preparation course']

for column in categorical_columns:
    plt.figure(figsize=(5, 5))
    df[column].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, cmap='Set3')
    plt.title(f'Percentage of {column.capitalize()}')
    plt.ylabel('')  # Menghilangkan label y untuk kejelasan
    plt.show()

# %% [markdown]
# Prompt:
#
# Dari kode berikut, beri style color yang aesthetic:
#
#
# ```
#
#
#
# import matplotlib.pyplot as plt
#
# def plot_pie_chart(column_name):
#
#     data = df[column_name].value_counts()
#     labels = data.index
#     sizes = data.values
#
#
#     plt.figure(figsize=(7,7))
#     plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, colors=plt.cm.Paired.colors)
#     plt.axis('equal')  # Untuk memastikan pie chart berbentuk lingkaran
#     plt.title(f'Percentage of {column_name}')
#     plt.show()
#
# plot_pie_chart('gender')
#
#
# plot_pie_chart('race/ethnicity')
# plot_pie_chart('lunch')
# plot_pie_chart('parental level of education')
# plot_pie_chart('test preparation course')
#
# ```

# %%
import matplotlib.pyplot as plt

def plot_pie_chart(column_name, colormap='Pastel1'):
    data = df[column_name].value_counts()
    labels = data.index
    sizes = data.values

    plt.figure(figsize=(8, 8))
    colors = plt.get_cmap(colormap).colors[:len(labels)]  # Pilih warna dari colormap

    wedges, texts, autotexts = plt.pie(
        sizes, labels=labels, autopct='%1.1f%%', startangle=90,
        colors=colors, textprops={'fontsize': 12, 'color': 'black'}
    )

    # Styling setiap text untuk membuatnya lebih estetis
    for text in texts:
        text.set_fontsize(13)
        text.set_color("darkslategray")
    for autotext in autotexts:
        autotext.set_fontsize(12)
        autotext.set_color("white")
        autotext.set_weight("bold")

    plt.axis('equal')  # Agar pie chart tetap berbentuk lingkaran
    plt.title(f'Percentage of {column_name}', fontsize=15, color="slategray", fontweight='bold')
    plt.show()

# Plot dengan warna yang lebih estetis
plot_pie_chart('gender', 'Pastel2')
plot_pie_chart('race/ethnicity', 'Set3')
plot_pie_chart('lunch', 'Pastel1')
plot_pie_chart('parental level of education', 'Set3')
plot_pie_chart('test preparation course', 'Pastel2')

# %% [markdown]
# Prompt:
#
# Dari kode berikut, beri style warm color:
#
#
# ```
#
#
#
# import matplotlib.pyplot as plt
#
# def plot_pie_chart(column_name):
#
#     data = df[column_name].value_counts()
#     labels = data.index
#     sizes = data.values
#
#
#     plt.figure(figsize=(7,7))
#     plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, colors=plt.cm.Paired.colors)
#     plt.axis('equal')  # Untuk memastikan pie chart berbentuk lingkaran
#     plt.title(f'Percentage of {column_name}')
#     plt.show()
#
# plot_pie_chart('gender')
#
#
# plot_pie_chart('race/ethnicity')
# plot_pie_chart('lunch')
# plot_pie_chart('parental level of education')
# plot_pie_chart('test preparation course')
#
# ```

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_pie_chart(column_name, colormap='OrRd'):
    # Mengambil data dan label dari kolom yang dipilih
    data = df[column_name].value_counts()
    labels = data.index
    sizes = data.values

    # Membuat ukuran figure
    plt.figure(figsize=(5, 5))

    # Get the colormap
    cmap = plt.get_cmap(colormap)

    # Generate colors based on the number of labels
    colors = [cmap(i) for i in np.linspace(0, 1, len(labels))]

    wedges, texts, autotexts = plt.pie(
        sizes, labels=labels, autopct='%1.1f%%', startangle=90,
        colors=colors, textprops={'fontsize': 12, 'color': 'black'}
    )

    # Styling setiap text untuk membuatnya lebih estetis
    for text in texts:
        text.set_fontsize(13)
        text.set_color("maroon")
    for autotext in autotexts:
        autotext.set_fontsize(12)
        autotext.set_color("white")
        autotext.set_weight("bold")

    plt.axis('equal')  # Agar pie chart tetap berbentuk lingkaran
    plt.title(f'Percentage of {column_name}', fontsize=15, color="firebrick", fontweight='bold')
    plt.show()

# Menggunakan palet warna yang warm
plot_pie_chart('gender', 'OrRd')
plot_pie_chart('race/ethnicity', 'autumn')
plot_pie_chart('lunch', 'OrRd')
plot_pie_chart('parental level of education', 'autumn')
plot_pie_chart('test preparation course', 'OrRd')

# %% [markdown]
# Prompt:
#
# Beri kode python yang menunjukkan visualisasi nilai math, reading, dan writing siswa, dengan melihat pengaruh dari gender, race/ethnicity, parental level of education, lunch, test preparation course-nya!

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Memuat dataset
df = pd.read_csv('/content/StudentsPerformance.csv')

# Mengatur ukuran dan gaya untuk semua plot
plt.figure(figsize=(15, 10))
sns.set_style("whitegrid")

# Membuat plot untuk pengaruh `gender` terhadap nilai
plt.subplot(2, 3, 1)
sns.boxplot(x='gender', y='math score', data=df, palette="Wistia")
plt.title("Math Score by Gender")

plt.subplot(2, 3, 2)
sns.boxplot(x='gender', y='reading score', data=df, palette="Wistia")
plt.title("Reading Score by Gender")

plt.subplot(2, 3, 3)
sns.boxplot(x='gender', y='writing score', data=df, palette="Wistia")
plt.title("Writing Score by Gender")

# Membuat plot untuk pengaruh `race/ethnicity` terhadap nilai
plt.subplot(2, 3, 4)
sns.boxplot(x='race/ethnicity', y='math score', data=df, palette="OrRd")
plt.title("Math Score by Race/Ethnicity")

plt.subplot(2, 3, 5)
sns.boxplot(x='race/ethnicity', y='reading score', data=df, palette="OrRd")
plt.title("Reading Score by Race/Ethnicity")

plt.subplot(2, 3, 6)
sns.boxplot(x='race/ethnicity', y='writing score', data=df, palette="OrRd")
plt.title("Writing Score by Race/Ethnicity")

plt.tight_layout()
plt.show()

# Plot tambahan untuk `parental level of education`, `lunch`, dan `test preparation course`
fig, axes = plt.subplots(3, 3, figsize=(18, 12))

# Parental level of education
sns.boxplot(ax=axes[0, 0], x='parental level of education', y='math score', data=df, palette="YlOrBr")
axes[0, 0].set_title("Math Score by Parental Level of Education")
sns.boxplot(ax=axes[0, 1], x='parental level of education', y='reading score', data=df, palette="YlOrBr")
axes[0, 1].set_title("Reading Score by Parental Level of Education")
sns.boxplot(ax=axes[0, 2], x='parental level of education', y='writing score', data=df, palette="YlOrBr")
axes[0, 2].set_title("Writing Score by Parental Level of Education")

# Lunch
sns.boxplot(ax=axes[1, 0], x='lunch', y='math score', data=df, palette="PuRd")
axes[1, 0].set_title("Math Score by Lunch")
sns.boxplot(ax=axes[1, 1], x='lunch', y='reading score', data=df, palette="PuRd")
axes[1, 1].set_title("Reading Score by Lunch")
sns.boxplot(ax=axes[1, 2], x='lunch', y='writing score', data=df, palette="PuRd")
axes[1, 2].set_title("Writing Score by Lunch")

# Test preparation course
sns.boxplot(ax=axes[2, 0], x='test preparation course', y='math score', data=df, palette="BuPu")
axes[2, 0].set_title("Math Score by Test Preparation Course")
sns.boxplot(ax=axes[2, 1], x='test preparation course', y='reading score', data=df, palette="BuPu")
axes[2, 1].set_title("Reading Score by Test Preparation Course")
sns.boxplot(ax=axes[2, 2], x='test preparation course', y='writing score', data=df, palette="BuPu")
axes[2, 2].set_title("Writing Score by Test Preparation Course")

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-16-11f5a5fdca0f>:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='gender', y='math score', data=df, palette="Wistia")
# <ipython-input-16-11f5a5fdca0f>:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='gender', y='reading score', data=df, palette="Wistia")
# <ipython-input-16-11f5a5fdca0f>:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='gender', y='writing score', data=df, palette="Wistia")
# <ipython-input-16-11f5a5fdca0f>:27: FutureWarning:
#
# ...

# %% [markdown]
# Prompt:
#
# Dari kode berikut, beri style pastle color:
#
#
# ```
#
#
#
# import matplotlib.pyplot as plt
#
# def plot_pie_chart(column_name):
#
#     data = df[column_name].value_counts()
#     labels = data.index
#     sizes = data.values
#
#
#     plt.figure(figsize=(7,7))
#     plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, colors=plt.cm.Paired.colors)
#     plt.axis('equal')  # Untuk memastikan pie chart berbentuk lingkaran
#     plt.title(f'Percentage of {column_name}')
#     plt.show()
#
# plot_pie_chart('gender')
#
#
# plot_pie_chart('race/ethnicity')
# plot_pie_chart('lunch')
# plot_pie_chart('parental level of education')
# plot_pie_chart('test preparation course')
#
# ```

# %%
import matplotlib.pyplot as plt

def plot_pie_chart(column_name, colormap='Pastel2'):
    # Mengambil data dan label dari kolom yang dipilih
    data = df[column_name].value_counts()
    labels = data.index
    sizes = data.values

    # Membuat ukuran figure
    plt.figure(figsize=(8, 8))
    colors = plt.get_cmap(colormap).colors[:len(labels)]  # Menggunakan warna pastel dari colormap

    wedges, texts, autotexts = plt.pie(
        sizes, labels=labels, autopct='%1.1f%%', startangle=90,
        colors=colors, textprops={'fontsize': 12, 'color': 'black'}
    )

    # Styling setiap teks agar sesuai dengan tema pastel
    for text in texts:
        text.set_fontsize(13)
        text.set_color("dimgray")
    for autotext in autotexts:
        autotext.set_fontsize(12)
        autotext.set_color("white")
        autotext.set_weight("bold")

    plt.axis('equal')  # Agar pie chart tetap berbentuk lingkaran
    plt.title(f'Percentage of {column_name}', fontsize=15, color="slategray", fontweight='bold')
    plt.show()

# Menggunakan warna pastel
plot_pie_chart('gender', 'Pastel1')
plot_pie_chart('race/ethnicity', 'Pastel2')
plot_pie_chart('lunch', 'Pastel1')
plot_pie_chart('parental level of education', 'Pastel2')
plot_pie_chart('test preparation course', 'Pastel1')

# %% [markdown]
# Prompt:
#
# Beri kode untuk melihat distribusi nilai math, reading dan writing dg informasi dataframe sebagai berikut:
#
# Data columns (total 8 columns):
#   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#
#  1   race/ethnicity               1000 non-null   object
#
#  2   parental level of education  1000 non-null   object
#
#  3   lunch                        1000 non-null   object
#
#  4   test preparation course      1000 non-null   object
#
#  5   math score                   1000 non-null   int64
#
#  6   reading score                1000 non-null   int64
#
#  7   writing score                1000 non-null   int64
#
# dtypes: int64(3), object(5)

# %%
# prompt: Beri kode untuk melihat distribusi nilai math, reading dan writing dg informasi dataframe sebagai berikut:
# Data columns (total 8 columns): Column Non-Null Count Dtype
# 0 gender 1000 non-null object
# 1 race/ethnicity 1000 non-null object
# 2 parental level of education 1000 non-null object
# 3 lunch 1000 non-null object
# 4 test preparation course 1000 non-null object
# 5 math score 1000 non-null int64
# 6 reading score 1000 non-null int64
# 7 writing score 1000 non-null int64
# dtypes: int64(3), object(5)

import matplotlib.pyplot as plt
import seaborn as sns

# Visualisasi distribusi nilai math, reading, dan writing
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
sns.histplot(df['math score'], kde=True, color='skyblue')
plt.title('Distribusi Nilai Matematika')

plt.subplot(1, 3, 2)
sns.histplot(df['reading score'], kde=True, color='salmon')
plt.title('Distribusi Nilai Membaca')

plt.subplot(1, 3, 3)
sns.histplot(df['writing score'], kde=True, color='lightgreen')
plt.title('Distribusi Nilai Menulis')

plt.tight_layout()
plt.show()

# Boxplot untuk melihat distribusi nilai math, reading, dan writing
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
sns.boxplot(y='math score', data=df, color='skyblue')
plt.title('Boxplot Nilai Matematika')

plt.subplot(1, 3, 2)
sns.boxplot(y='reading score', data=df, color='salmon')
plt.title('Boxplot Nilai Membaca')

plt.subplot(1, 3, 3)
sns.boxplot(y='writing score', data=df, color='lightgreen')
plt.title('Boxplot Nilai Menulis')

plt.tight_layout()
plt.show()

# %% [markdown]
# Prompt:
#
# Beri kode python untuk melihat jumlah siswa yang fail dan pass untuk masing-masing pelajaran (math, reading, writing score). Dengan minimal nilai yang dianggap pass adalah 75!

# %%
import pandas as pd

# Memuat dataset
df = pd.read_csv('/content/StudentsPerformance.csv')

# Menambahkan kolom baru untuk status kelulusan (Pass atau Fail) pada setiap mata pelajaran
df['math_status'] = df['math score'].apply(lambda x: 'Pass' if x >= 75 else 'Fail')
df['reading_status'] = df['reading score'].apply(lambda x: 'Pass' if x >= 75 else 'Fail')
df['writing_status'] = df['writing score'].apply(lambda x: 'Pass' if x >= 75 else 'Fail')

# Menghitung jumlah siswa yang Pass dan Fail untuk masing-masing pelajaran
math_counts = df['math_status'].value_counts()
reading_counts = df['reading_status'].value_counts()
writing_counts = df['writing_status'].value_counts()

# Menampilkan hasil
print("Math Pass/Fail Counts:")
print(math_counts)
print("\nReading Pass/Fail Counts:")
print(reading_counts)
print("\nWriting Pass/Fail Counts:")
print(writing_counts)
# Out:
# Math Pass/Fail Counts:
# math_status
# Fail    705
# Pass    295
# Name: count, dtype: int64
#
# Reading Pass/Fail Counts:
# reading_status
# Fail    630
# Pass    370
# Name: count, dtype: int64
#
# Writing Pass/Fail Counts:
# writing_status
# Fail    650
# Pass    350
# Name: count, dtype: int64

# %% [markdown]
# Prompt:
#
# Beri kode python yang menunjukkan visualisasi nilai math, reading, dan writing siswa, dengan melihat pengaruh dari gender, race/ethnicity, parental level of education, lunch, test preparation course-nya!

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Memuat dataset
df = pd.read_csv('/content/StudentsPerformance.csv')

# Mengatur ukuran dan gaya visualisasi
plt.figure(figsize=(15, 10))
sns.set_style("whitegrid")

# Membuat plot untuk pengaruh `gender` terhadap nilai
plt.subplot(3, 3, 1)
sns.boxplot(x='gender', y='math score', data=df, palette="pastel")
plt.title("Math Score by Gender")

plt.subplot(3, 3, 2)
sns.boxplot(x='gender', y='reading score', data=df, palette="pastel")
plt.title("Reading Score by Gender")

plt.subplot(3, 3, 3)
sns.boxplot(x='gender', y='writing score', data=df, palette="pastel")
plt.title("Writing Score by Gender")

# Membuat plot untuk pengaruh `race/ethnicity` terhadap nilai
plt.subplot(3, 3, 4)
sns.boxplot(x='race/ethnicity', y='math score', data=df, palette="Set3")
plt.title("Math Score by Race/Ethnicity")

plt.subplot(3, 3, 5)
sns.boxplot(x='race/ethnicity', y='reading score', data=df, palette="Set3")
plt.title("Reading Score by Race/Ethnicity")

plt.subplot(3, 3, 6)
sns.boxplot(x='race/ethnicity', y='writing score', data=df, palette="Set3")
plt.title("Writing Score by Race/Ethnicity")

# Membuat plot untuk pengaruh `parental level of education` terhadap nilai
plt.subplot(3, 3, 7)
sns.boxplot(x='parental level of education', y='math score', data=df, palette="pastel")
plt.xticks(rotation=45)
plt.title("Math Score by Parental Level of Education")

plt.subplot(3, 3, 8)
sns.boxplot(x='parental level of education', y='reading score', data=df, palette="pastel")
plt.xticks(rotation=45)
plt.title("Reading Score by Parental Level of Education")

plt.subplot(3, 3, 9)
sns.boxplot(x='parental level of education', y='writing score', data=df, palette="pastel")
plt.xticks(rotation=45)
plt.title("Writing Score by Parental Level of Education")

plt.tight_layout()
plt.show()

# Visualisasi tambahan untuk `lunch` dan `test preparation course`
fig, axes = plt.subplots(2, 3, figsize=(15, 10))

sns.boxplot(ax=axes[0, 0], x='lunch', y='math score', data=df, palette="Blues")
axes[0, 0].set_title("Math Score by Lunch")

sns.boxplot(ax=axes[0, 1], x='lunch', y='reading score', data=df, palette="Blues")
axes[0, 1].set_title("Reading Score by Lunch")

sns.boxplot(ax=axes[0, 2], x='lunch', y='writing score', data=df, palette="Blues")
axes[0, 2].set_title("Writing Score by Lunch")

sns.boxplot(ax=axes[1, 0], x='test preparation course', y='math score', data=df, palette="Purples")
axes[1, 0].set_title("Math Score by Test Preparation Course")

sns.boxplot(ax=axes[1, 1], x='test preparation course', y='reading score', data=df, palette="Purples")
axes[1, 1].set_title("Reading Score by Test Preparation Course")

sns.boxplot(ax=axes[1, 2], x='test preparation course', y='writing score', data=df, palette="Purples")
axes[1, 2].set_title("Writing Score by Test Preparation Course")

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-22-1b85b6b62a5a>:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='gender', y='math score', data=df, palette="pastel")
# <ipython-input-22-1b85b6b62a5a>:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='gender', y='reading score', data=df, palette="pastel")
# <ipython-input-22-1b85b6b62a5a>:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='gender', y='writing score', data=df, palette="pastel")
# <ipython-input-22-1b85b6b62a5a>:27: FutureWarning:
#
# ...

# %% [markdown]
# Prompt: Beri kode untuk melihat nilai rata-rata seluruh mata pelajaran (math, reading writing) dari setiap siswa dan lihat korelasinya dengan masing-masing kategori

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Memuat dataset
df = pd.read_csv('/content/StudentsPerformance.csv')

# Menambahkan kolom baru untuk rata-rata nilai
df['average_score'] = df[['math score', 'reading score', 'writing score']].mean(axis=1)

# Menampilkan rata-rata nilai dari seluruh siswa
print("Rata-rata nilai seluruh mata pelajaran dari setiap siswa:")
print(df[['gender', 'race/ethnicity', 'parental level of education', 'lunch', 'test preparation course', 'average_score']].head())

# Visualisasi korelasi rata-rata nilai dengan kategori menggunakan boxplot
plt.figure(figsize=(15, 10))

# Korelasi dengan gender
plt.subplot(3, 2, 1)
sns.boxplot(x='gender', y='average_score', data=df, palette="pastel")
plt.title("Average Score by Gender")

# Korelasi dengan race/ethnicity
plt.subplot(3, 2, 2)
sns.boxplot(x='race/ethnicity', y='average_score', data=df, palette="Set3")
plt.title("Average Score by Race/Ethnicity")

# Korelasi dengan parental level of education
plt.subplot(3, 2, 3)
sns.boxplot(x='parental level of education', y='average_score', data=df, palette="pastel")
plt.xticks(rotation=45)
plt.title("Average Score by Parental Level of Education")

# Korelasi dengan lunch
plt.subplot(3, 2, 4)
sns.boxplot(x='lunch', y='average_score', data=df, palette="Blues")
plt.title("Average Score by Lunch")

# Korelasi dengan test preparation course
plt.subplot(3, 2, 5)
sns.boxplot(x='test preparation course', y='average_score', data=df, palette="Purples")
plt.title("Average Score by Test Preparation Course")

plt.tight_layout()
plt.show()
# Out:
# Rata-rata nilai seluruh mata pelajaran dari setiap siswa:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  average_score
# 0                    none      72.666667
# 1               completed      82.333333
# 2                    none      92.666667
# 3                    none      49.333333
# 4                    none      76.333333
# <ipython-input-23-e503c85fd320>:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...
